# %%
import pandas as pd

file = "./materials.csv"

# %%
df = pd.read_csv(file)

# %%
df
# Out:
#                          name     domain smiles  inchi_key  query match  \
# 0                   noble gas        Gas    NaN        NaN        0.000
# 1       electromagnetic field    Effects    NaN        NaN        0.000
# 2                      Plasma    Anatomy    NaN        NaN        0.000
# 3                acceleration    Effects    NaN        NaN        0.000
# 4                     gravity    Effects    NaN        NaN        0.000
# 5                 interaction    Effects    NaN        NaN        0.000
# 6                   anomalous    Effects    NaN        NaN        0.000
# 7              electric field    Effects    NaN        NaN        0.000
# 8               amplification    Effects    NaN        NaN        0.000
# 9   electromagnetic radiation    Effects    NaN        NaN        0.000
# 10              equilibration    Methods    NaN        NaN        0.000
# 11                   aluminum      Metal   [Al]        0.0  description
# ...
